# %% [markdown]
# # Using TensorBoard with custom training schedule
#
# The API for `tf.keras.callbacks.TensorBoard` is developed for use with the `Model.fit` method. However, since we have a complicated training step for the GAN, we have to use the `TensorBoard` callback as a normal function, and pass it the values of the losses and images that we want to record.
#
# Let's take the example of the MNIST training data set

# %%
import h5py
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from pathlib import Path
import os
import began
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Project directory
PROJ_DIR = Path("/home/bthorne/projects/gan/began")
# Model directory
MODEL_PATH = PROJ_DIR / "model" / "mnist_dcgan_NTRAIN50000.h5"

# Network architecture
DEPTH = 16
IMG_DIM = 28
CHANNELS = 1
KERNELS = [5, 5, 5]
STRIDES = [2, 2, 2]
FILTERS = [DEPTH * 2 ** i for i in range(len(KERNELS))]
LATENT_DIM = 32

# Derived parameters
SHAPE = (IMG_DIM, IMG_DIM, CHANNELS)

# Training parameters
TRAIN_STEPS = 50000
BATCH_SIZE = 32

# Build inidividual and joint models.
DIS = began.dcgan.build_discriminator(FILTERS, KERNELS, STRIDES, SHAPE)
GEN = began.dcgan.build_generator(DIS, FILTERS, KERNELS, STRIDES, LATENT_DIM, SHAPE)
ADV = began.dcgan.build_adversarial_model(DIS, GEN)
print(GEN.summary())
# Out:
# Model: "Generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Dense_G (Dense)              (None, 1024)              33792
# _________________________________________________________________
# Reshape (Reshape)            (None, 4, 4, 64)          0
# _________________________________________________________________
# BNorm_G1 (BatchNormalization (None, 4, 4, 64)          256
# _________________________________________________________________
# LRelu_G1 (LeakyReLU)         (None, 4, 4, 64)          0
# _________________________________________________________________
# UpSample_1 (UpSampling2D)    (None, 8, 8, 64)          0
# _________________________________________________________________
# Conv2D_G1 (Conv2D)           (None, 8, 8, 32)          51232
# _________________________________________________________________
# BN_G2 (BatchNormalization)   (None, 8, 8, 32)          128
# _________________________________________________________________
# LRelu_G2 (LeakyReLU)         (None, 8, 8, 32)          0
# _________________________________________________________________
# UpSample_2 (UpSampling2D)    (None, 16, 16, 32)        0
# _________________________________________________________________
# Conv2D_G2 (Conv2D)           (None, 16, 16, 16)        12816
# _________________________________________________________________
# BN_G3 (BatchNormalization)   (None, 16, 16, 16)        64
# _________________________________________________________________
# LRelu_G3 (LeakyReLU)         (None, 16, 16, 16)        0
# _________________________________________________________________
# UpSample_3 (UpSampling2D)    (None, 32, 32, 16)        0
# _________________________________________________________________
# Conv2D_G3 (Conv2D)           (None, 32, 32, 1)         401
# _________________________________________________________________
# Tanh (Activation)            (None, 32, 32, 1)         0
# _________________________________________________________________
# Crop2D (Cropping2D)          (None, 28, 28, 1)         0
# =================================================================
# Total params: 98,689
# Trainable params: 98,465
# Non-trainable params: 224
# _________________________________________________________________
# None

# %%
# Load raw training data
(X_TRAIN, _), (_, _) = mnist.load_data()

# Apply preprocessing to scale data
X_TRAIN = X_TRAIN[..., None] / 255. * 2. - 1.

# %%
# Setup logging
logdir = "logs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S")
file_writer = tf.summary.create_file_writer(logdir + "/metrics")
file_writer.set_as_default()
tboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tboard_callback.set_model(DIS)

image_lat = np.random.randn(1, LATENT_DIM)
for step in range(TRAIN_STEPS):
        tf.summary.experimental.set_step(step)
        # First train the discriminator with correct labels
        # Randomly select batch from training samples
        y_real = np.random.binomial(1, 0.99, size=[BATCH_SIZE, 1])
        y_fake = np.random.binomial(1, 0.01, size=[BATCH_SIZE, 1])
        idx = np.random.randint(0, X_TRAIN.shape[0], size=BATCH_SIZE)

        images_real = X_TRAIN[idx, ...]

        # Use `generator` to create fake images.
        noise = np.random.normal(loc=0., scale=1., size=[BATCH_SIZE, LATENT_DIM])
        images_fake = GEN.predict(noise)

        # Train the discriminator on real and fake images.
        dloss_real = DIS.train_on_batch(images_real, y_real)
        dloss_fake = DIS.train_on_batch(images_fake, y_fake)
        dloss = 0.5 * (dloss_real + dloss_fake)
        # Now train the adversarial network.
        # Create new fake images, and label as if they are from the training set.
        # Lie indicates that we are tricking the adversarial network by
        # telling it the target is valid, when in reality the discriminator
        # is being fed fake images by the generator.
        y_lie = np.ones([BATCH_SIZE, 1])
        noise = np.random.normal(loc=0., scale=1., size=[BATCH_SIZE, LATENT_DIM])
        a_loss = ADV.train_on_batch(noise, y_lie)
        tf.summary.image('lat_sample', GEN.predict(np.random.randn(4, LATENT_DIM)))
        tf.summary.image('random_draw', GEN.predict(image_lat))
        tf.summary.scalar('aloss', a_loss)
        tf.summary.scalar('dloss', dloss)
        #tboard_callback.on_train_batch_end(batch=step)
        if not step % 10:
            print("Step {:05d}, dloss {:.03f}".format(step, dloss))
# Out:
# Step 00000, dloss 1.013
# Step 00010, dloss 0.199
# Step 00020, dloss 0.762
# Step 00030, dloss 0.311
# Step 00040, dloss 0.331
# Step 00050, dloss 0.260
# Step 00060, dloss 0.271
# Step 00070, dloss 0.139
# Step 00080, dloss 0.149
# Step 00090, dloss 0.186
# Step 00100, dloss 0.099
# Step 00110, dloss 0.087
# Step 00120, dloss 0.136
# Step 00130, dloss 0.076
# Step 00140, dloss 0.066
# Step 00150, dloss 0.062
# Step 00160, dloss 0.176
# Step 00170, dloss 0.143
# Step 00180, dloss 0.147
# Step 00190, dloss 0.129
# Step 00200, dloss 0.103
# Step 00210, dloss 0.103
# Step 00220, dloss 0.123
# Step 00230, dloss 0.057
# Step 00240, dloss 0.093
# Step 00250, dloss 0.050
# Step 00260, dloss 0.086
# Step 00270, dloss 0.043
# Step 00280, dloss 0.033
# Step 00290, dloss 0.026
# Step 00300, dloss 0.080
# Step 00310, dloss 0.086
# Step 00320, dloss 0.074
# Step 00330, dloss 0.015
# Step 00340, dloss 0.098
# Step 00350, dloss 0.031
# Step 00360, dloss 0.006
# Step 00370, dloss 0.109
# Step 00380, dloss 0.087
# Step 00390, dloss 0.023
# Step 00400, dloss 0.225
# Step 00410, dloss 0.181
# Step 00420, dloss 0.008
# Step 00430, dloss 0.007
# Step 00440, dloss 0.092
# Step 00450, dloss 0.005
# Step 00460, dloss 0.078
# Step 00470, dloss 0.019
# Step 00480, dloss 0.063
# Step 00490, dloss 0.071
# Step 00500, dloss 0.055
# Step 00510, dloss 0.075
# Step 00520, dloss 0.013
# Step 00530, dloss 0.014
# Step 00540, dloss 0.145
# Step 00550, dloss 0.017
# Step 00560, dloss 0.096
# Step 00570, dloss 0.018
# Step 00580, dloss 0.011
# Step 00590, dloss 0.079
# Step 00600, dloss 0.011
# Step 00610, dloss 0.069
# Step 00620, dloss 0.012
# Step 00630, dloss 0.074
# Step 00640, dloss 0.007
# Step 00650, dloss 0.010
# Step 00660, dloss 0.002
# Step 00670, dloss 0.005
# Step 00680, dloss 0.141
# Step 00690, dloss 0.104
# Step 00700, dloss 0.014
# Step 00710, dloss 0.157
# Step 00720, dloss 0.013
# Step 00730, dloss 0.119
# Step 00740, dloss 0.341
# Step 00750, dloss 0.012
# Step 00760, dloss 0.062
# Step 00770, dloss 0.009
# Step 00780, dloss 0.012
# Step 00790, dloss 0.164
# Step 00800, dloss 0.088
# Step 00810, dloss 0.009
# Step 00820, dloss 0.009
# Step 00830, dloss 0.074
# Step 00840, dloss 0.117
# Step 00850, dloss 0.092
# Step 00860, dloss 0.087
# Step 00870, dloss 0.007
# Step 00880, dloss 0.188
# Step 00890, dloss 0.082
# Step 00900, dloss 0.008
# Step 00910, dloss 0.094
# Step 00920, dloss 0.011
# Step 00930, dloss 0.006
# Step 00940, dloss 0.180
# Step 00950, dloss 0.090
# Step 00960, dloss 0.009
# Step 00970, dloss 0.163
# Step 00980, dloss 0.012
# Step 00990, dloss 0.095
# Step 01000, dloss 0.004
# Step 01010, dloss 0.005
# Step 01020, dloss 0.097
# Step 01030, dloss 0.015
# Step 01040, dloss 0.004
# Step 01050, dloss 0.010
# Step 01060, dloss 0.176
# Step 01070, dloss 0.005
# Step 01080, dloss 0.086
# Step 01090, dloss 0.007
# Step 01100, dloss 0.004
# Step 01110, dloss 0.011
# Step 01120, dloss 0.018
# Step 01130, dloss 0.075
# Step 01140, dloss 0.007
# Step 01150, dloss 0.093
# Step 01160, dloss 0.177
# Step 01170, dloss 0.008
# Step 01180, dloss 0.176
# Step 01190, dloss 0.088
# Step 01200, dloss 0.074
# Step 01210, dloss 0.086
# Step 01220, dloss 0.071
# Step 01230, dloss 0.011
# Step 01240, dloss 0.014
# Step 01250, dloss 0.097
# Step 01260, dloss 0.177
# Step 01270, dloss 0.052
# Step 01280, dloss 0.079
# Step 01290, dloss 0.293
# Step 01300, dloss 0.076
# Step 01310, dloss 0.008
# Step 01320, dloss 0.101
# Step 01330, dloss 0.008
# Step 01340, dloss 0.009
# Step 01350, dloss 0.005
# Step 01360, dloss 0.008
# Step 01370, dloss 0.106
# Step 01380, dloss 0.099
# Step 01390, dloss 0.010
# Step 01400, dloss 0.020
# Step 01410, dloss 0.075
# Step 01420, dloss 0.158
# Step 01430, dloss 0.082
# Step 01440, dloss 0.012
# Step 01450, dloss 0.015
# Step 01460, dloss 0.081
# Step 01470, dloss 0.070
# Step 01480, dloss 0.146
# Step 01490, dloss 0.168
# Step 01500, dloss 0.031
# Step 01510, dloss 0.029
# Step 01520, dloss 0.080
# Step 01530, dloss 0.006
# Step 01540, dloss 0.016
# Step 01550, dloss 0.085
# Step 01560, dloss 0.080
# Step 01570, dloss 0.009
# Step 01580, dloss 0.010
# Step 01590, dloss 0.027
# Step 01600, dloss 0.081
# Step 01610, dloss 0.015
# Step 01620, dloss 0.011
# Step 01630, dloss 0.083
# Step 01640, dloss 0.087
# Step 01650, dloss 0.078
# Step 01660, dloss 0.105
# Step 01670, dloss 0.324
# Step 01680, dloss 0.011
# Step 01690, dloss 0.013
# Step 01700, dloss 0.008
# Step 01710, dloss 0.078
# Step 01720, dloss 0.011
# Step 01730, dloss 0.255
# Step 01740, dloss 0.126
# Step 01750, dloss 0.072
# Step 01760, dloss 0.178
# Step 01770, dloss 0.098
# Step 01780, dloss 0.008
# Step 01790, dloss 0.004
# Step 01800, dloss 0.075
# Step 01810, dloss 0.072
# Step 01820, dloss 0.090
# Step 01830, dloss 0.007
# Step 01840, dloss 0.269
# Step 01850, dloss 0.011
# Step 01860, dloss 0.160
# Step 01870, dloss 0.009
# Step 01880, dloss 0.081
# Step 01890, dloss 0.009
# Step 01900, dloss 0.006
# Step 01910, dloss 0.009
# Step 01920, dloss 0.013
# Step 01930, dloss 0.006
# Step 01940, dloss 0.007
# Step 01950, dloss 0.162
# Step 01960, dloss 0.081
# Step 01970, dloss 0.105
# Step 01980, dloss 0.006
# Step 01990, dloss 0.011
# Step 02000, dloss 0.007
# Step 02010, dloss 0.006
# Step 02020, dloss 0.089
# Step 02030, dloss 0.083
# Step 02040, dloss 0.010
# Step 02050, dloss 0.173
# Step 02060, dloss 0.008
# Step 02070, dloss 0.008
# Step 02080, dloss 0.010
# Step 02090, dloss 0.011
# Step 02100, dloss 0.081
# Step 02110, dloss 0.015
# Step 02120, dloss 0.077
# Step 02130, dloss 0.009
# Step 02140, dloss 0.075
# Step 02150, dloss 0.014
# Step 02160, dloss 0.085
# Step 02170, dloss 0.008
# Step 02180, dloss 0.171
# Step 02190, dloss 0.007
# Step 02200, dloss 0.133
# Step 02210, dloss 0.014
# Step 02220, dloss 0.151
# Step 02230, dloss 0.019
# Step 02240, dloss 0.016
# Step 02250, dloss 0.012
# Step 02260, dloss 0.094
# Step 02270, dloss 0.165
# Step 02280, dloss 0.017
# Step 02290, dloss 0.105
# Step 02300, dloss 0.009
# Step 02310, dloss 0.087
# Step 02320, dloss 0.085
# Step 02330, dloss 0.076
# Step 02340, dloss 0.189
# Step 02350, dloss 0.011
# Step 02360, dloss 0.014
# Step 02370, dloss 0.087
# Step 02380, dloss 0.012
# Step 02390, dloss 0.009
# Step 02400, dloss 0.004
# Step 02410, dloss 0.018
# Step 02420, dloss 0.019
# Step 02430, dloss 0.006
# Step 02440, dloss 0.175
# Step 02450, dloss 0.071
# Step 02460, dloss 0.005
# Step 02470, dloss 0.079
# Step 02480, dloss 0.095
# Step 02490, dloss 0.007
# Step 02500, dloss 0.013
# Step 02510, dloss 0.081
# Step 02520, dloss 0.010
# Step 02530, dloss 0.007
# Step 02540, dloss 0.006
# Step 02550, dloss 0.163
# Step 02560, dloss 0.081
# Step 02570, dloss 0.077
# Step 02580, dloss 0.007
# Step 02590, dloss 0.160
# Step 02600, dloss 0.009
# Step 02610, dloss 0.091
# Step 02620, dloss 0.015
# Step 02630, dloss 0.096
# Step 02640, dloss 0.009
# Step 02650, dloss 0.015
# Step 02660, dloss 0.110
# Step 02670, dloss 0.154
# Step 02680, dloss 0.024
# Step 02690, dloss 0.016
# Step 02700, dloss 0.089
# Step 02710, dloss 0.011
# Step 02720, dloss 0.195
# Step 02730, dloss 0.074
# Step 02740, dloss 0.152
# Step 02750, dloss 0.152
# Step 02760, dloss 0.086
# Step 02770, dloss 0.010
# Step 02780, dloss 0.100
# Step 02790, dloss 0.116
# Step 02800, dloss 0.009
# Step 02810, dloss 0.012
# Step 02820, dloss 0.033
# Step 02830, dloss 0.073
# Step 02840, dloss 0.009
# Step 02850, dloss 0.006
# Step 02860, dloss 0.165
# Step 02870, dloss 0.010
# Step 02880, dloss 0.009
# Step 02890, dloss 0.067
# Step 02900, dloss 0.084
# Step 02910, dloss 0.007
# Step 02920, dloss 0.076
# Step 02930, dloss 0.194
# Step 02940, dloss 0.064
# Step 02950, dloss 0.337
# Step 02960, dloss 0.015
# Step 02970, dloss 0.010
# Step 02980, dloss 0.005
# Step 02990, dloss 0.280
# Step 03000, dloss 0.014
# Step 03010, dloss 0.095
# Step 03020, dloss 0.007
# Step 03030, dloss 0.250
# Step 03040, dloss 0.076
# Step 03050, dloss 0.010
# Step 03060, dloss 0.094
# Step 03070, dloss 0.011
# Step 03080, dloss 0.011
# Step 03090, dloss 0.019
# Step 03100, dloss 0.017
# Step 03110, dloss 0.014
# Step 03120, dloss 0.013
# Step 03130, dloss 0.081
# Step 03140, dloss 0.021
# Step 03150, dloss 0.092
# Step 03160, dloss 0.011
# Step 03170, dloss 0.158
# Step 03180, dloss 0.010
# Step 03190, dloss 0.009
# Step 03200, dloss 0.007
# Step 03210, dloss 0.092
# Step 03220, dloss 0.013
# Step 03230, dloss 0.246
# Step 03240, dloss 0.177
# Step 03250, dloss 0.079
# Step 03260, dloss 0.012
# Step 03270, dloss 0.182
# Step 03280, dloss 0.011
# Step 03290, dloss 0.079
# Step 03300, dloss 0.009
# Step 03310, dloss 0.093
# Step 03320, dloss 0.007
# Step 03330, dloss 0.008
# Step 03340, dloss 0.153
# Step 03350, dloss 0.010
# Step 03360, dloss 0.011
# Step 03370, dloss 0.012
# Step 03380, dloss 0.006
# Step 03390, dloss 0.214
# Step 03400, dloss 0.089
# Step 03410, dloss 0.008
# Step 03420, dloss 0.158
# Step 03430, dloss 0.155
# Step 03440, dloss 0.137
# Step 03450, dloss 0.016
# Step 03460, dloss 0.012
# Step 03470, dloss 0.008
# Step 03480, dloss 0.008
# Step 03490, dloss 0.006
# Step 03500, dloss 0.090
# Step 03510, dloss 0.008
# Step 03520, dloss 0.007
# Step 03530, dloss 0.009
# Step 03540, dloss 0.008
# Step 03550, dloss 0.088
# Step 03560, dloss 0.089
# Step 03570, dloss 0.009
# Step 03580, dloss 0.019
# Step 03590, dloss 0.019
# Step 03600, dloss 0.092
# Step 03610, dloss 0.008
# Step 03620, dloss 0.080
# Step 03630, dloss 0.090
# Step 03640, dloss 0.007
# Step 03650, dloss 0.015
# Step 03660, dloss 0.016
# Step 03670, dloss 0.006
# Step 03680, dloss 0.156
# Step 03690, dloss 0.014
# Step 03700, dloss 0.078
# Step 03710, dloss 0.107
# Step 03720, dloss 0.079
# Step 03730, dloss 0.078
# Step 03740, dloss 0.008
# Step 03750, dloss 0.007
# Step 03760, dloss 0.158
# Step 03770, dloss 0.010
# Step 03780, dloss 0.092
# Step 03790, dloss 0.008
# Step 03800, dloss 0.006
# Step 03810, dloss 0.183
# Step 03820, dloss 0.186
# Step 03830, dloss 0.011
# Step 03840, dloss 0.007
# Step 03850, dloss 0.080
# Step 03860, dloss 0.162
# Step 03870, dloss 0.086
# Step 03880, dloss 0.086
# Step 03890, dloss 0.013
# Step 03900, dloss 0.168
# Step 03910, dloss 0.006
# Step 03920, dloss 0.008
# Step 03930, dloss 0.008
# Step 03940, dloss 0.006
# Step 03950, dloss 0.087
# Step 03960, dloss 0.010
# Step 03970, dloss 0.091
# Step 03980, dloss 0.007
# Step 03990, dloss 0.013
# Step 04000, dloss 0.009
# Step 04010, dloss 0.008
# Step 04020, dloss 0.095
# Step 04030, dloss 0.089
# Step 04040, dloss 0.106
# Step 04050, dloss 0.010
# Step 04060, dloss 0.265
# Step 04070, dloss 0.089
# Step 04080, dloss 0.004
# Step 04090, dloss 0.009
# Step 04100, dloss 0.007
# Step 04110, dloss 0.014
# Step 04120, dloss 0.091
# Step 04130, dloss 0.176
# Step 04140, dloss 0.161
# Step 04150, dloss 0.083
# Step 04160, dloss 0.011
# Step 04170, dloss 0.018
# Step 04180, dloss 0.010
# Step 04190, dloss 0.163
# Step 04200, dloss 0.008
# Step 04210, dloss 0.090
# Step 04220, dloss 0.075
# Step 04230, dloss 0.081
# Step 04240, dloss 0.011
# Step 04250, dloss 0.007
# Step 04260, dloss 0.076
# Step 04270, dloss 0.008
# Step 04280, dloss 0.008
# Step 04290, dloss 0.091
# Step 04300, dloss 0.009
# Step 04310, dloss 0.097
# Step 04320, dloss 0.072
# Step 04330, dloss 0.009
# Step 04340, dloss 0.094
# Step 04350, dloss 0.074
# Step 04360, dloss 0.013
# Step 04370, dloss 0.073
# Step 04380, dloss 0.125
# Step 04390, dloss 0.019
# Step 04400, dloss 0.014
# Step 04410, dloss 0.007
# Step 04420, dloss 0.158
# Step 04430, dloss 0.010
# Step 04440, dloss 0.019
# Step 04450, dloss 0.013
# Step 04460, dloss 0.114
# Step 04470, dloss 0.076
# Step 04480, dloss 0.073
# Step 04490, dloss 0.106
# Step 04500, dloss 0.009
# Step 04510, dloss 0.084
# Step 04520, dloss 0.010
# Step 04530, dloss 0.008
# Step 04540, dloss 0.137
# Step 04550, dloss 0.005
# Step 04560, dloss 0.006
# Step 04570, dloss 0.072
# Step 04580, dloss 0.189
# Step 04590, dloss 0.195
# Step 04600, dloss 0.017
# Step 04610, dloss 0.074
# Step 04620, dloss 0.092
# Step 04630, dloss 0.011
# Step 04640, dloss 0.163
# Step 04650, dloss 0.012
# Step 04660, dloss 0.009
# Step 04670, dloss 0.010
# Step 04680, dloss 0.011
# Step 04690, dloss 0.011
# Step 04700, dloss 0.008
# Step 04710, dloss 0.115
# Step 04720, dloss 0.014
# Step 04730, dloss 0.102
# Step 04740, dloss 0.006
# Step 04750, dloss 0.088
# Step 04760, dloss 0.009
# Step 04770, dloss 0.092
# Step 04780, dloss 0.008
# Step 04790, dloss 0.013
# Step 04800, dloss 0.085
# Step 04810, dloss 0.102
# Step 04820, dloss 0.007
# Step 04830, dloss 0.079
# Step 04840, dloss 0.082
# Step 04850, dloss 0.072
# Step 04860, dloss 0.061
# Step 04870, dloss 0.250
# Step 04880, dloss 0.153
# Step 04890, dloss 0.011
# Step 04900, dloss 0.018
# Step 04910, dloss 0.093
# Step 04920, dloss 0.205
# Step 04930, dloss 0.327
# Step 04940, dloss 0.025
# Step 04950, dloss 0.093
# Step 04960, dloss 0.178
# Step 04970, dloss 0.084
# Step 04980, dloss 0.091
# Step 04990, dloss 0.075
# Step 05000, dloss 0.006
# Step 05010, dloss 0.153
# Step 05020, dloss 0.010
# Step 05030, dloss 0.017
# Step 05040, dloss 0.235
# Step 05050, dloss 0.007
# Step 05060, dloss 0.013
# Step 05070, dloss 0.169
# Step 05080, dloss 0.181
# Step 05090, dloss 0.008
# Step 05100, dloss 0.011
# Step 05110, dloss 0.078
# Step 05120, dloss 0.006
# Step 05130, dloss 0.115
# Step 05140, dloss 0.010
# Step 05150, dloss 0.103
# Step 05160, dloss 0.011
# Step 05170, dloss 0.018
# Step 05180, dloss 0.013
# Step 05190, dloss 0.009
# Step 05200, dloss 0.108
# Step 05210, dloss 0.091
# Step 05220, dloss 0.007
# Step 05230, dloss 0.101
# Step 05240, dloss 0.011
# Step 05250, dloss 0.013
# Step 05260, dloss 0.011
# Step 05270, dloss 0.082
# Step 05280, dloss 0.153
# Step 05290, dloss 0.082
# Step 05300, dloss 0.006
# Step 05310, dloss 0.077
# Step 05320, dloss 0.081
# Step 05330, dloss 0.087
# Step 05340, dloss 0.091
# Step 05350, dloss 0.084
# Step 05360, dloss 0.009
# Step 05370, dloss 0.158
# Step 05380, dloss 0.092
# Step 05390, dloss 0.011
# Step 05400, dloss 0.104
# Step 05410, dloss 0.075
# Step 05420, dloss 0.090
# Step 05430, dloss 0.084
# Step 05440, dloss 0.151
# Step 05450, dloss 0.011
# Step 05460, dloss 0.078
# Step 05470, dloss 0.085
# Step 05480, dloss 0.007
# Step 05490, dloss 0.231
# Step 05500, dloss 0.159
# Step 05510, dloss 0.009
# Step 05520, dloss 0.109
# Step 05530, dloss 0.006
# Step 05540, dloss 0.007
# Step 05550, dloss 0.008
# Step 05560, dloss 0.013
# Step 05570, dloss 0.013
# Step 05580, dloss 0.081
# Step 05590, dloss 0.087
# Step 05600, dloss 0.009
# Step 05610, dloss 0.088
# Step 05620, dloss 0.012
# Step 05630, dloss 0.010
# Step 05640, dloss 0.012
# Step 05650, dloss 0.025
# Step 05660, dloss 0.016
# Step 05670, dloss 0.019
# Step 05680, dloss 0.078
# Step 05690, dloss 0.011
# Step 05700, dloss 0.012
# Step 05710, dloss 0.006
# Step 05720, dloss 0.008
# Step 05730, dloss 0.165
# Step 05740, dloss 0.094
# Step 05750, dloss 0.079
# Step 05760, dloss 0.055
# Step 05770, dloss 0.042
# Step 05780, dloss 0.017
# Step 05790, dloss 0.026
# Step 05800, dloss 0.023
# Step 05810, dloss 0.018
# Step 05820, dloss 0.019
# Step 05830, dloss 0.045
# Step 05840, dloss 0.093
# Step 05850, dloss 0.066
# Step 05860, dloss 0.014
# Step 05870, dloss 0.009
# Step 05880, dloss 0.168
# Step 05890, dloss 0.172
# Step 05900, dloss 0.094
# Step 05910, dloss 0.021
# Step 05920, dloss 0.066
# Step 05930, dloss 0.097
# Step 05940, dloss 0.011
# Step 05950, dloss 0.096
# Step 05960, dloss 0.006
# Step 05970, dloss 0.182
# Step 05980, dloss 0.106
# Step 05990, dloss 0.084
# Step 06000, dloss 0.005
# Step 06010, dloss 0.078
# Step 06020, dloss 0.078
# Step 06030, dloss 0.014
# Step 06040, dloss 0.080
# Step 06050, dloss 0.012
# Step 06060, dloss 0.006
# Step 06070, dloss 0.090
# Step 06080, dloss 0.013
# Step 06090, dloss 0.009
# Step 06100, dloss 0.005
# Step 06110, dloss 0.088
# Step 06120, dloss 0.009
# Step 06130, dloss 0.017
# Step 06140, dloss 0.079
# Step 06150, dloss 0.013
# Step 06160, dloss 0.014
# Step 06170, dloss 0.072
# Step 06180, dloss 0.077
# Step 06190, dloss 0.159
# Step 06200, dloss 0.014
# Step 06210, dloss 0.082
# Step 06220, dloss 0.074
# Step 06230, dloss 0.223
# Step 06240, dloss 0.156
# Step 06250, dloss 0.014
# Step 06260, dloss 0.156
# Step 06270, dloss 0.098
# Step 06280, dloss 0.009
# Step 06290, dloss 0.008
# Step 06300, dloss 0.173
# Step 06310, dloss 0.013
# Step 06320, dloss 0.013
# Step 06330, dloss 0.009
# Step 06340, dloss 0.085
# Step 06350, dloss 0.013
# Step 06360, dloss 0.012
# Step 06370, dloss 0.012
# Step 06380, dloss 0.013
# Step 06390, dloss 0.008
# Step 06400, dloss 0.078
# Step 06410, dloss 0.077
# Step 06420, dloss 0.096
# Step 06430, dloss 0.008
# Step 06440, dloss 0.011
# Step 06450, dloss 0.007
# Step 06460, dloss 0.016
# Step 06470, dloss 0.089
# Step 06480, dloss 0.086
# Step 06490, dloss 0.087
# Step 06500, dloss 0.150
# Step 06510, dloss 0.090
# Step 06520, dloss 0.007
# Step 06530, dloss 0.086
# Step 06540, dloss 0.013
# Step 06550, dloss 0.069
# Step 06560, dloss 0.013
# Step 06570, dloss 0.095
# Step 06580, dloss 0.009
# Step 06590, dloss 0.184
# Step 06600, dloss 0.010
# Step 06610, dloss 0.011
# Step 06620, dloss 0.007
# Step 06630, dloss 0.006
# Step 06640, dloss 0.081
# Step 06650, dloss 0.010
# Step 06660, dloss 0.009
# Step 06670, dloss 0.008
# Step 06680, dloss 0.088
# Step 06690, dloss 0.104
# Step 06700, dloss 0.009
# Step 06710, dloss 0.012
# Step 06720, dloss 0.084
# Step 06730, dloss 0.085
# Step 06740, dloss 0.010
# Step 06750, dloss 0.012
# Step 06760, dloss 0.079
# Step 06770, dloss 0.008
# Step 06780, dloss 0.152
# Step 06790, dloss 0.097
# Step 06800, dloss 0.009
# Step 06810, dloss 0.158
# Step 06820, dloss 0.007
# Step 06830, dloss 0.010
# Step 06840, dloss 0.012
# Step 06850, dloss 0.089
# Step 06860, dloss 0.011
# Step 06870, dloss 0.144
# Step 06880, dloss 0.011
# Step 06890, dloss 0.010
# Step 06900, dloss 0.086
# Step 06910, dloss 0.076
# Step 06920, dloss 0.010
# Step 06930, dloss 0.007
# Step 06940, dloss 0.083
# Step 06950, dloss 0.015
# Step 06960, dloss 0.013
# Step 06970, dloss 0.006
# Step 06980, dloss 0.170
# Step 06990, dloss 0.013
# Step 07000, dloss 0.011
# Step 07010, dloss 0.086
# Step 07020, dloss 0.154
# Step 07030, dloss 0.018
# Step 07040, dloss 0.009
# Step 07050, dloss 0.016
# Step 07060, dloss 0.016
# Step 07070, dloss 0.013
# Step 07080, dloss 0.169
# Step 07090, dloss 0.008
# Step 07100, dloss 0.012
# Step 07110, dloss 0.014
# Step 07120, dloss 0.013
# Step 07130, dloss 0.079
# Step 07140, dloss 0.092
# Step 07150, dloss 0.159
# Step 07160, dloss 0.012
# Step 07170, dloss 0.006
# Step 07180, dloss 0.084
# Step 07190, dloss 0.087
# Step 07200, dloss 0.017
# Step 07210, dloss 0.008
# Step 07220, dloss 0.008
# Step 07230, dloss 0.009
# Step 07240, dloss 0.014
# Step 07250, dloss 0.005
# Step 07260, dloss 0.087
# Step 07270, dloss 0.012
# Step 07280, dloss 0.099
# Step 07290, dloss 0.012
# Step 07300, dloss 0.016
# Step 07310, dloss 0.010
# Step 07320, dloss 0.161
# Step 07330, dloss 0.008
# Step 07340, dloss 0.008
# Step 07350, dloss 0.007
# Step 07360, dloss 0.092
# Step 07370, dloss 0.162
# Step 07380, dloss 0.007
# Step 07390, dloss 0.010
# Step 07400, dloss 0.157
# Step 07410, dloss 0.013
# Step 07420, dloss 0.008
# Step 07430, dloss 0.089
# Step 07440, dloss 0.138
# Step 07450, dloss 0.147
# Step 07460, dloss 0.010
# Step 07470, dloss 0.164
# Step 07480, dloss 0.011
# Step 07490, dloss 0.014
# Step 07500, dloss 0.174
# Step 07510, dloss 0.013
# Step 07520, dloss 0.091
# Step 07530, dloss 0.010
# Step 07540, dloss 0.074
# Step 07550, dloss 0.169
# Step 07560, dloss 0.080
# Step 07570, dloss 0.081
# Step 07580, dloss 0.006
# Step 07590, dloss 0.168
# Step 07600, dloss 0.013
# Step 07610, dloss 0.154
# Step 07620, dloss 0.011
# Step 07630, dloss 0.094
# Step 07640, dloss 0.090
# Step 07650, dloss 0.006
# Step 07660, dloss 0.008
# Step 07670, dloss 0.088
# Step 07680, dloss 0.006
# Step 07690, dloss 0.177
# Step 07700, dloss 0.159
# Step 07710, dloss 0.013
# Step 07720, dloss 0.009
# Step 07730, dloss 0.008
# Step 07740, dloss 0.019
# Step 07750, dloss 0.017
# Step 07760, dloss 0.151
# Step 07770, dloss 0.084
# Step 07780, dloss 0.079
# Step 07790, dloss 0.083
# Step 07800, dloss 0.070
# Step 07810, dloss 0.013
# Step 07820, dloss 0.008
# Step 07830, dloss 0.117
# Step 07840, dloss 0.094
# Step 07850, dloss 0.089
# Step 07860, dloss 0.084
# Step 07870, dloss 0.088
# Step 07880, dloss 0.014
# Step 07890, dloss 0.008
# Step 07900, dloss 0.008
# Step 07910, dloss 0.011
# Step 07920, dloss 0.039
# Step 07930, dloss 0.088
# Step 07940, dloss 0.176
# Step 07950, dloss 0.094
# Step 07960, dloss 0.146
# Step 07970, dloss 0.211
# Step 07980, dloss 0.009
# Step 07990, dloss 0.079
# Step 08000, dloss 0.009
# Step 08010, dloss 0.008
# Step 08020, dloss 0.133
# Step 08030, dloss 0.013
# Step 08040, dloss 0.008
# Step 08050, dloss 0.006
# Step 08060, dloss 0.008
# Step 08070, dloss 0.009
# Step 08080, dloss 0.012
# Step 08090, dloss 0.089
# Step 08100, dloss 0.165
# Step 08110, dloss 0.081
# Step 08120, dloss 0.016
# Step 08130, dloss 0.012
# Step 08140, dloss 0.010
# Step 08150, dloss 0.086
# Step 08160, dloss 0.008
# Step 08170, dloss 0.009
# Step 08180, dloss 0.006
# Step 08190, dloss 0.008
# Step 08200, dloss 0.170
# Step 08210, dloss 0.081
# Step 08220, dloss 0.009
# Step 08230, dloss 0.144
# Step 08240, dloss 0.013
# Step 08250, dloss 0.166
# Step 08260, dloss 0.008
# Step 08270, dloss 0.076
# Step 08280, dloss 0.078
# Step 08290, dloss 0.163
# Step 08300, dloss 0.090
# Step 08310, dloss 0.069
# Step 08320, dloss 0.080
# Step 08330, dloss 0.099
# Step 08340, dloss 0.083
# Step 08350, dloss 0.011
# Step 08360, dloss 0.209
# Step 08370, dloss 0.011
# Step 08380, dloss 0.072
# Step 08390, dloss 0.074
# Step 08400, dloss 0.008
# Step 08410, dloss 0.008
# Step 08420, dloss 0.082
# Step 08430, dloss 0.081
# Step 08440, dloss 0.094
# Step 08450, dloss 0.007
# Step 08460, dloss 0.008
# Step 08470, dloss 0.086
# Step 08480, dloss 0.151
# Step 08490, dloss 0.008
# Step 08500, dloss 0.075
# Step 08510, dloss 0.174
# Step 08520, dloss 0.165
# Step 08530, dloss 0.076
# Step 08540, dloss 0.089
# Step 08550, dloss 0.014
# Step 08560, dloss 0.091
# Step 08570, dloss 0.017
# Step 08580, dloss 0.085
# Step 08590, dloss 0.087
# Step 08600, dloss 0.082
# Step 08610, dloss 0.145
# Step 08620, dloss 0.008
# Step 08630, dloss 0.008
# Step 08640, dloss 0.089
# Step 08650, dloss 0.013
# Step 08660, dloss 0.087
# Step 08670, dloss 0.088
# Step 08680, dloss 0.007
# Step 08690, dloss 0.018
# Step 08700, dloss 0.144
# Step 08710, dloss 0.045
# Step 08720, dloss 0.010
# Step 08730, dloss 0.009
# Step 08740, dloss 0.007
# Step 08750, dloss 0.228
# Step 08760, dloss 0.012
# Step 08770, dloss 0.007
# Step 08780, dloss 0.004
# Step 08790, dloss 0.006
# Step 08800, dloss 0.007
# Step 08810, dloss 0.009
# Step 08820, dloss 0.007
# Step 08830, dloss 0.068
# Step 08840, dloss 0.174
# Step 08850, dloss 0.011
# Step 08860, dloss 0.010
# Step 08870, dloss 0.011
# Step 08880, dloss 0.006
# Step 08890, dloss 0.097
# Step 08900, dloss 0.009
# Step 08910, dloss 0.081
# Step 08920, dloss 0.013
# Step 08930, dloss 0.008
# Step 08940, dloss 0.007
# Step 08950, dloss 0.182
# Step 08960, dloss 0.010
# Step 08970, dloss 0.011
# Step 08980, dloss 0.085
# Step 08990, dloss 0.010
# Step 09000, dloss 0.010
# Step 09010, dloss 0.007
# Step 09020, dloss 0.020
# Step 09030, dloss 0.090
# Step 09040, dloss 0.015
# Step 09050, dloss 0.010
# Step 09060, dloss 0.010
# Step 09070, dloss 0.010
# Step 09080, dloss 0.216
# Step 09090, dloss 0.163
# Step 09100, dloss 0.080
# Step 09110, dloss 0.016
# Step 09120, dloss 0.010
# Step 09130, dloss 0.084
# Step 09140, dloss 0.103
# Step 09150, dloss 0.007
# Step 09160, dloss 0.011
# Step 09170, dloss 0.009
# Step 09180, dloss 0.095
# Step 09190, dloss 0.010
# Step 09200, dloss 0.141
# Step 09210, dloss 0.007
# Step 09220, dloss 0.010
# Step 09230, dloss 0.080
# Step 09240, dloss 0.011
# Step 09250, dloss 0.076
# Step 09260, dloss 0.013
# Step 09270, dloss 0.011
# Step 09280, dloss 0.171
# Step 09290, dloss 0.017
# Step 09300, dloss 0.010
# Step 09310, dloss 0.008
# Step 09320, dloss 0.009
# Step 09330, dloss 0.140
# Step 09340, dloss 0.008
# Step 09350, dloss 0.085
# Step 09360, dloss 0.086
# Step 09370, dloss 0.085
# Step 09380, dloss 0.084
# Step 09390, dloss 0.073
# Step 09400, dloss 0.085
# Step 09410, dloss 0.084
# Step 09420, dloss 0.007
# Step 09430, dloss 0.009
# Step 09440, dloss 0.167
# Step 09450, dloss 0.018
# Step 09460, dloss 0.009
# Step 09470, dloss 0.006
# Step 09480, dloss 0.006
# Step 09490, dloss 0.078
# Step 09500, dloss 0.082
# Step 09510, dloss 0.085
# Step 09520, dloss 0.012
# Step 09530, dloss 0.086
# Step 09540, dloss 0.009
# Step 09550, dloss 0.094
# Step 09560, dloss 0.086
# Step 09570, dloss 0.009
# Step 09580, dloss 0.188
# Step 09590, dloss 0.009
# Step 09600, dloss 0.008
# Step 09610, dloss 0.147
# Step 09620, dloss 0.020
# Step 09630, dloss 0.021
# Step 09640, dloss 0.015
# Step 09650, dloss 0.007
# Step 09660, dloss 0.006
# Step 09670, dloss 0.087
# Step 09680, dloss 0.090
# Step 09690, dloss 0.010
# Step 09700, dloss 0.008
# Step 09710, dloss 0.101
# Step 09720, dloss 0.012
# Step 09730, dloss 0.012
# Step 09740, dloss 0.010
# Step 09750, dloss 0.010
# Step 09760, dloss 0.207
# Step 09770, dloss 0.015
# Step 09780, dloss 0.147
# Step 09790, dloss 0.088
# Step 09800, dloss 0.136
# Step 09810, dloss 0.009
# Step 09820, dloss 0.010
# Step 09830, dloss 0.008
# Step 09840, dloss 0.009
# Step 09850, dloss 0.009
# Step 09860, dloss 0.006
# Step 09870, dloss 0.085
# Step 09880, dloss 0.214
# Step 09890, dloss 0.081
# Step 09900, dloss 0.193
# Step 09910, dloss 0.135
# Step 09920, dloss 0.082
# Step 09930, dloss 0.011
# Step 09940, dloss 0.086
# Step 09950, dloss 0.007
# Step 09960, dloss 0.077
# Step 09970, dloss 0.010
# Step 09980, dloss 0.016
# Step 09990, dloss 0.109
# Step 10000, dloss 0.086
# Step 10010, dloss 0.014
# Step 10020, dloss 0.105
# Step 10030, dloss 0.100
# Step 10040, dloss 0.008
# Step 10050, dloss 0.006
# Step 10060, dloss 0.007
# Step 10070, dloss 0.013
# Step 10080, dloss 0.011
# Step 10090, dloss 0.092
# Step 10100, dloss 0.072
# Step 10110, dloss 0.225
# Step 10120, dloss 0.075
# Step 10130, dloss 0.077
# Step 10140, dloss 0.259
# Step 10150, dloss 0.009
# Step 10160, dloss 0.117
# Step 10170, dloss 0.083
# Step 10180, dloss 0.084
# Step 10190, dloss 0.010
# Step 10200, dloss 0.009
# Step 10210, dloss 0.016
# Step 10220, dloss 0.096
# Step 10230, dloss 0.024
# Step 10240, dloss 0.174
# Step 10250, dloss 0.014
# Step 10260, dloss 0.154
# Step 10270, dloss 0.085
# Step 10280, dloss 0.012
# Step 10290, dloss 0.116
# Step 10300, dloss 0.008
# Step 10310, dloss 0.006
# Step 10320, dloss 0.013
# Step 10330, dloss 0.077
# Step 10340, dloss 0.010
# Step 10350, dloss 0.013
# Step 10360, dloss 0.012
# Step 10370, dloss 0.079
# Step 10380, dloss 0.007
# Step 10390, dloss 0.087
# Step 10400, dloss 0.084
# Step 10410, dloss 0.007
# Step 10420, dloss 0.182
# Step 10430, dloss 0.167
# Step 10440, dloss 0.089
# Step 10450, dloss 0.010
# Step 10460, dloss 0.010
# Step 10470, dloss 0.091
# Step 10480, dloss 0.011
# Step 10490, dloss 0.079
# Step 10500, dloss 0.078
# Step 10510, dloss 0.091
# Step 10520, dloss 0.008
# Step 10530, dloss 0.016
# Step 10540, dloss 0.080
# Step 10550, dloss 0.086
# Step 10560, dloss 0.078
# Step 10570, dloss 0.016
# Step 10580, dloss 0.083
# Step 10590, dloss 0.010
# Step 10600, dloss 0.081
# Step 10610, dloss 0.004
# Step 10620, dloss 0.007
# Step 10630, dloss 0.084
# Step 10640, dloss 0.009
# Step 10650, dloss 0.176
# Step 10660, dloss 0.077
# Step 10670, dloss 0.009
# Step 10680, dloss 0.106
# Step 10690, dloss 0.087
# Step 10700, dloss 0.013
# Step 10710, dloss 0.010
# Step 10720, dloss 0.016
# Step 10730, dloss 0.091
# Step 10740, dloss 0.012
# Step 10750, dloss 0.011
# Step 10760, dloss 0.083
# Step 10770, dloss 0.073
# Step 10780, dloss 0.011
# Step 10790, dloss 0.072
# Step 10800, dloss 0.013
# Step 10810, dloss 0.013
# Step 10820, dloss 0.014
# Step 10830, dloss 0.156
# Step 10840, dloss 0.151
# Step 10850, dloss 0.021
# Step 10860, dloss 0.009
# Step 10870, dloss 0.008
# Step 10880, dloss 0.007
# Step 10890, dloss 0.007
# Step 10900, dloss 0.084
# Step 10910, dloss 0.097
# Step 10920, dloss 0.078
# Step 10930, dloss 0.137
# Step 10940, dloss 0.010
# Step 10950, dloss 0.010
# Step 10960, dloss 0.085
# Step 10970, dloss 0.094
# Step 10980, dloss 0.007
# Step 10990, dloss 0.081
# Step 11000, dloss 0.082
# Step 11010, dloss 0.086
# Step 11020, dloss 0.093
# Step 11030, dloss 0.084
# Step 11040, dloss 0.010
# Step 11050, dloss 0.012
# Step 11060, dloss 0.009
# Step 11070, dloss 0.011
# Step 11080, dloss 0.008
# Step 11090, dloss 0.169
# Step 11100, dloss 0.008
# Step 11110, dloss 0.083
# Step 11120, dloss 0.008
# Step 11130, dloss 0.010
# Step 11140, dloss 0.088
# Step 11150, dloss 0.011
# Step 11160, dloss 0.155
# Step 11170, dloss 0.011
# Step 11180, dloss 0.011
# Step 11190, dloss 0.009
# Step 11200, dloss 0.008
# Step 11210, dloss 0.076
# Step 11220, dloss 0.248
# Step 11230, dloss 0.008
# Step 11240, dloss 0.095
# Step 11250, dloss 0.015
# Step 11260, dloss 0.010
# Step 11270, dloss 0.006
# Step 11280, dloss 0.092
# Step 11290, dloss 0.077
# Step 11300, dloss 0.006
# Step 11310, dloss 0.077
# Step 11320, dloss 0.086
# Step 11330, dloss 0.081
# Step 11340, dloss 0.016
# Step 11350, dloss 0.026
# Step 11360, dloss 0.144
# Step 11370, dloss 0.077
# Step 11380, dloss 0.162
# Step 11390, dloss 0.109
# Step 11400, dloss 0.161
# Step 11410, dloss 0.079
# Step 11420, dloss 0.175
# Step 11430, dloss 0.007
# Step 11440, dloss 0.088
# Step 11450, dloss 0.157
# Step 11460, dloss 0.144
# Step 11470, dloss 0.145
# Step 11480, dloss 0.016
# Step 11490, dloss 0.011
# Step 11500, dloss 0.077
# Step 11510, dloss 0.013
# Step 11520, dloss 0.012
# Step 11530, dloss 0.007
# Step 11540, dloss 0.007
# Step 11550, dloss 0.008
# Step 11560, dloss 0.073
# Step 11570, dloss 0.073
# Step 11580, dloss 0.081
# Step 11590, dloss 0.085
# Step 11600, dloss 0.082
# Step 11610, dloss 0.074
# Step 11620, dloss 0.160
# Step 11630, dloss 0.089
# Step 11640, dloss 0.009
# Step 11650, dloss 0.008
# Step 11660, dloss 0.093
# Step 11670, dloss 0.011
# Step 11680, dloss 0.145
# Step 11690, dloss 0.014
# Step 11700, dloss 0.095
# Step 11710, dloss 0.151
# Step 11720, dloss 0.014
# Step 11730, dloss 0.152
# Step 11740, dloss 0.015
# Step 11750, dloss 0.013
# Step 11760, dloss 0.010
# Step 11770, dloss 0.010
# Step 11780, dloss 0.079
# Step 11790, dloss 0.084
# Step 11800, dloss 0.009
# Step 11810, dloss 0.085
# Step 11820, dloss 0.084
# Step 11830, dloss 0.092
# Step 11840, dloss 0.080
# Step 11850, dloss 0.013
# Step 11860, dloss 0.295
# Step 11870, dloss 0.086
# Step 11880, dloss 0.010
# Step 11890, dloss 0.011
# Step 11900, dloss 0.081
# Step 11910, dloss 0.091
# Step 11920, dloss 0.013
# Step 11930, dloss 0.010
# Step 11940, dloss 0.101
# Step 11950, dloss 0.013
# Step 11960, dloss 0.016
# Step 11970, dloss 0.079
# Step 11980, dloss 0.081
# Step 11990, dloss 0.164
# Step 12000, dloss 0.016
# Step 12010, dloss 0.253
# Step 12020, dloss 0.007
# Step 12030, dloss 0.008
# Step 12040, dloss 0.007
# Step 12050, dloss 0.097
# Step 12060, dloss 0.156
# Step 12070, dloss 0.010
# Step 12080, dloss 0.010
# Step 12090, dloss 0.152
# Step 12100, dloss 0.069
# Step 12110, dloss 0.086
# Step 12120, dloss 0.015
# Step 12130, dloss 0.016
# Step 12140, dloss 0.012
# Step 12150, dloss 0.159
# Step 12160, dloss 0.083
# Step 12170, dloss 0.014
# Step 12180, dloss 0.009
# Step 12190, dloss 0.080
# Step 12200, dloss 0.148
# Step 12210, dloss 0.008
# Step 12220, dloss 0.013
# Step 12230, dloss 0.008
# Step 12240, dloss 0.081
# Step 12250, dloss 0.010
# Step 12260, dloss 0.010
# Step 12270, dloss 0.007
# Step 12280, dloss 0.094
# Step 12290, dloss 0.007
# Step 12300, dloss 0.009
# Step 12310, dloss 0.005
# Step 12320, dloss 0.087
# Step 12330, dloss 0.007
# Step 12340, dloss 0.086
# Step 12350, dloss 0.013
# Step 12360, dloss 0.079
# Step 12370, dloss 0.081
# Step 12380, dloss 0.090
# Step 12390, dloss 0.085
# Step 12400, dloss 0.011
# Step 12410, dloss 0.007
# Step 12420, dloss 0.007
# Step 12430, dloss 0.144
# Step 12440, dloss 0.105
# Step 12450, dloss 0.098
# Step 12460, dloss 0.007
# Step 12470, dloss 0.086
# Step 12480, dloss 0.008
# Step 12490, dloss 0.078
# Step 12500, dloss 0.086
# Step 12510, dloss 0.085
# Step 12520, dloss 0.084
# Step 12530, dloss 0.160
# Step 12540, dloss 0.242
# Step 12550, dloss 0.076
# Step 12560, dloss 0.091
# Step 12570, dloss 0.011
# Step 12580, dloss 0.009
# Step 12590, dloss 0.011
# Step 12600, dloss 0.010
# Step 12610, dloss 0.011
# Step 12620, dloss 0.008
# Step 12630, dloss 0.013
# Step 12640, dloss 0.157
# Step 12650, dloss 0.145
# Step 12660, dloss 0.088
# Step 12670, dloss 0.009
# Step 12680, dloss 0.081
# Step 12690, dloss 0.012
# Step 12700, dloss 0.153
# Step 12710, dloss 0.009
# Step 12720, dloss 0.085
# Step 12730, dloss 0.013
# Step 12740, dloss 0.011
# Step 12750, dloss 0.010
# Step 12760, dloss 0.009
# Step 12770, dloss 0.007
# Step 12780, dloss 0.007
# Step 12790, dloss 0.170
# Step 12800, dloss 0.012
# Step 12810, dloss 0.076
# Step 12820, dloss 0.090
# Step 12830, dloss 0.082
# Step 12840, dloss 0.008
# Step 12850, dloss 0.008
# Step 12860, dloss 0.008
# Step 12870, dloss 0.078
# Step 12880, dloss 0.159
# Step 12890, dloss 0.141
# Step 12900, dloss 0.008
# Step 12910, dloss 0.085
# Step 12920, dloss 0.013
# Step 12930, dloss 0.080
# Step 12940, dloss 0.082
# Step 12950, dloss 0.088
# Step 12960, dloss 0.008
# Step 12970, dloss 0.094
# Step 12980, dloss 0.075
# Step 12990, dloss 0.080
# Step 13000, dloss 0.009
# Step 13010, dloss 0.205
# Step 13020, dloss 0.086
# Step 13030, dloss 0.012
# Step 13040, dloss 0.011
# Step 13050, dloss 0.160
# Step 13060, dloss 0.009
# Step 13070, dloss 0.152
# Step 13080, dloss 0.011
# Step 13090, dloss 0.080
# Step 13100, dloss 0.086
# Step 13110, dloss 0.081
# Step 13120, dloss 0.010
# Step 13130, dloss 0.007
# Step 13140, dloss 0.236
# Step 13150, dloss 0.153
# Step 13160, dloss 0.009
# Step 13170, dloss 0.079
# Step 13180, dloss 0.070
# Step 13190, dloss 0.009
# Step 13200, dloss 0.155
# Step 13210, dloss 0.008
# Step 13220, dloss 0.090
# Step 13230, dloss 0.007
# Step 13240, dloss 0.133
# Step 13250, dloss 0.088
# Step 13260, dloss 0.078
# Step 13270, dloss 0.149
# Step 13280, dloss 0.084
# Step 13290, dloss 0.011
# Step 13300, dloss 0.117
# Step 13310, dloss 0.018
# Step 13320, dloss 0.085
# Step 13330, dloss 0.017
# Step 13340, dloss 0.027
# Step 13350, dloss 0.036
# Step 13360, dloss 0.122
# Step 13370, dloss 0.088
# Step 13380, dloss 0.076
# Step 13390, dloss 0.084
# Step 13400, dloss 0.185
# Step 13410, dloss 0.006
# Step 13420, dloss 0.157
# Step 13430, dloss 0.016
# Step 13440, dloss 0.152
# Step 13450, dloss 0.079
# Step 13460, dloss 0.012
# Step 13470, dloss 0.017
# Step 13480, dloss 0.153
# Step 13490, dloss 0.010
# Step 13500, dloss 0.007
# Step 13510, dloss 0.005
# Step 13520, dloss 0.005
# Step 13530, dloss 0.006
# Step 13540, dloss 0.006
# Step 13550, dloss 0.013
# Step 13560, dloss 0.010
# Step 13570, dloss 0.007
# Step 13580, dloss 0.011
# Step 13590, dloss 0.086
# Step 13600, dloss 0.012
# Step 13610, dloss 0.082
# Step 13620, dloss 0.090
# Step 13630, dloss 0.085
# Step 13640, dloss 0.009
# Step 13650, dloss 0.152
# Step 13660, dloss 0.011
# Step 13670, dloss 0.014
# Step 13680, dloss 0.137
# Step 13690, dloss 0.103
# Step 13700, dloss 0.009
# Step 13710, dloss 0.012
# Step 13720, dloss 0.010
# Step 13730, dloss 0.008
# Step 13740, dloss 0.008
# Step 13750, dloss 0.162
# Step 13760, dloss 0.008
# Step 13770, dloss 0.006
# Step 13780, dloss 0.007
# Step 13790, dloss 0.008
# Step 13800, dloss 0.090
# Step 13810, dloss 0.008
# Step 13820, dloss 0.007
# Step 13830, dloss 0.287
# Step 13840, dloss 0.007
# Step 13850, dloss 0.160
# Step 13860, dloss 0.008
# Step 13870, dloss 0.008
# Step 13880, dloss 0.010
# Step 13890, dloss 0.159
# Step 13900, dloss 0.010
# Step 13910, dloss 0.008
# Step 13920, dloss 0.084
# Step 13930, dloss 0.089
# Step 13940, dloss 0.008
# Step 13950, dloss 0.145
# Step 13960, dloss 0.010
# Step 13970, dloss 0.012
# Step 13980, dloss 0.007
# Step 13990, dloss 0.010
# Step 14000, dloss 0.092
# Step 14010, dloss 0.011
# Step 14020, dloss 0.074
# Step 14030, dloss 0.136
# Step 14040, dloss 0.077
# Step 14050, dloss 0.089
# Step 14060, dloss 0.170
# Step 14070, dloss 0.009
# Step 14080, dloss 0.087
# Step 14090, dloss 0.086
# Step 14100, dloss 0.083
# Step 14110, dloss 0.081
# Step 14120, dloss 0.010
# Step 14130, dloss 0.013
# Step 14140, dloss 0.010
# Step 14150, dloss 0.079
# Step 14160, dloss 0.010
# Step 14170, dloss 0.010
# Step 14180, dloss 0.013
# Step 14190, dloss 0.008
# Step 14200, dloss 0.012
# Step 14210, dloss 0.013
# Step 14220, dloss 0.009
# Step 14230, dloss 0.008
# Step 14240, dloss 0.008
# Step 14250, dloss 0.008
# Step 14260, dloss 0.008
# Step 14270, dloss 0.007
# Step 14280, dloss 0.086
# Step 14290, dloss 0.088
# Step 14300, dloss 0.082
# Step 14310, dloss 0.084
# Step 14320, dloss 0.087
# Step 14330, dloss 0.008
# Step 14340, dloss 0.172
# Step 14350, dloss 0.015
# Step 14360, dloss 0.013
# Step 14370, dloss 0.085
# Step 14380, dloss 0.012
# Step 14390, dloss 0.081
# Step 14400, dloss 0.078
# Step 14410, dloss 0.089
# Step 14420, dloss 0.012
# Step 14430, dloss 0.082
# Step 14440, dloss 0.078
# Step 14450, dloss 0.008
# Step 14460, dloss 0.009
# Step 14470, dloss 0.081
# Step 14480, dloss 0.008
# Step 14490, dloss 0.011
# Step 14500, dloss 0.085
# Step 14510, dloss 0.087
# Step 14520, dloss 0.077
# Step 14530, dloss 0.011
# Step 14540, dloss 0.011
# Step 14550, dloss 0.159
# Step 14560, dloss 0.011
# Step 14570, dloss 0.010
# Step 14580, dloss 0.009
# Step 14590, dloss 0.082
# Step 14600, dloss 0.009
# Step 14610, dloss 0.086
# Step 14620, dloss 0.080
# Step 14630, dloss 0.078
# Step 14640, dloss 0.085
# Step 14650, dloss 0.083
# Step 14660, dloss 0.076
# Step 14670, dloss 0.078
# Step 14680, dloss 0.010
# Step 14690, dloss 0.009
# Step 14700, dloss 0.073
# Step 14710, dloss 0.009
# Step 14720, dloss 0.009
# Step 14730, dloss 0.010
# Step 14740, dloss 0.153
# Step 14750, dloss 0.087
# Step 14760, dloss 0.092
# Step 14770, dloss 0.080
# Step 14780, dloss 0.009
# Step 14790, dloss 0.017
# Step 14800, dloss 0.009
# Step 14810, dloss 0.012
# Step 14820, dloss 0.008
# Step 14830, dloss 0.010
# Step 14840, dloss 0.011
# Step 14850, dloss 0.159
# Step 14860, dloss 0.082
# Step 14870, dloss 0.013
# Step 14880, dloss 0.083
# Step 14890, dloss 0.145
# Step 14900, dloss 0.088
# Step 14910, dloss 0.013
# Step 14920, dloss 0.083
# Step 14930, dloss 0.217
# Step 14940, dloss 0.236
# Step 14950, dloss 0.014
# Step 14960, dloss 0.012
# Step 14970, dloss 0.010
# Step 14980, dloss 0.014
# Step 14990, dloss 0.014
# Step 15000, dloss 0.085
# Step 15010, dloss 0.011
# Step 15020, dloss 0.013
# Step 15030, dloss 0.011
# Step 15040, dloss 0.008
# Step 15050, dloss 0.146
# Step 15060, dloss 0.011
# Step 15070, dloss 0.155
# Step 15080, dloss 0.071
# Step 15090, dloss 0.088
# Step 15100, dloss 0.084
# Step 15110, dloss 0.009
# Step 15120, dloss 0.012
# Step 15130, dloss 0.009
# Step 15140, dloss 0.008
# Step 15150, dloss 0.088
# Step 15160, dloss 0.076
# Step 15170, dloss 0.188
# Step 15180, dloss 0.011
# Step 15190, dloss 0.008
# Step 15200, dloss 0.081
# Step 15210, dloss 0.008
# Step 15220, dloss 0.163
# Step 15230, dloss 0.014
# Step 15240, dloss 0.242
# Step 15250, dloss 0.077
# Step 15260, dloss 0.079
# Step 15270, dloss 0.011
# Step 15280, dloss 0.087
# Step 15290, dloss 0.085
# Step 15300, dloss 0.078
# Step 15310, dloss 0.082
# Step 15320, dloss 0.011
# Step 15330, dloss 0.011
# Step 15340, dloss 0.092
# Step 15350, dloss 0.016
# Step 15360, dloss 0.080
# Step 15370, dloss 0.014
# Step 15380, dloss 0.084
# Step 15390, dloss 0.070
# Step 15400, dloss 0.013
# Step 15410, dloss 0.240
# Step 15420, dloss 0.084
# Step 15430, dloss 0.012
# Step 15440, dloss 0.010
# Step 15450, dloss 0.082
# Step 15460, dloss 0.083
# Step 15470, dloss 0.081
# Step 15480, dloss 0.083
# Step 15490, dloss 0.015
# Step 15500, dloss 0.146
# Step 15510, dloss 0.012
# Step 15520, dloss 0.009
# Step 15530, dloss 0.086
# Step 15540, dloss 0.013
# Step 15550, dloss 0.088
# Step 15560, dloss 0.020
# Step 15570, dloss 0.068
# Step 15580, dloss 0.166
# Step 15590, dloss 0.015
# Step 15600, dloss 0.009
# Step 15610, dloss 0.078
# Step 15620, dloss 0.010
# Step 15630, dloss 0.011
# Step 15640, dloss 0.088
# Step 15650, dloss 0.008
# Step 15660, dloss 0.086
# Step 15670, dloss 0.014
# Step 15680, dloss 0.088
# Step 15690, dloss 0.009
# Step 15700, dloss 0.012
# Step 15710, dloss 0.009
# Step 15720, dloss 0.164
# Step 15730, dloss 0.168
# Step 15740, dloss 0.084
# Step 15750, dloss 0.013
# Step 15760, dloss 0.161
# Step 15770, dloss 0.081
# Step 15780, dloss 0.010
# Step 15790, dloss 0.009
# Step 15800, dloss 0.088
# Step 15810, dloss 0.009
# Step 15820, dloss 0.008
# Step 15830, dloss 0.083
# Step 15840, dloss 0.010
# Step 15850, dloss 0.086
# Step 15860, dloss 0.011
# Step 15870, dloss 0.007
# Step 15880, dloss 0.010
# Step 15890, dloss 0.011
# Step 15900, dloss 0.078
# Step 15910, dloss 0.007
# Step 15920, dloss 0.168
# Step 15930, dloss 0.008
# Step 15940, dloss 0.083
# Step 15950, dloss 0.080
# Step 15960, dloss 0.009
# Step 15970, dloss 0.011
# Step 15980, dloss 0.008
# Step 15990, dloss 0.009
# Step 16000, dloss 0.007
# Step 16010, dloss 0.168
# Step 16020, dloss 0.011
# Step 16030, dloss 0.010
# Step 16040, dloss 0.006
# Step 16050, dloss 0.172
# Step 16060, dloss 0.005
# Step 16070, dloss 0.008
# Step 16080, dloss 0.006
# Step 16090, dloss 0.009
# Step 16100, dloss 0.009
# Step 16110, dloss 0.008
# Step 16120, dloss 0.005
# Step 16130, dloss 0.089
# Step 16140, dloss 0.008
# Step 16150, dloss 0.081
# Step 16160, dloss 0.008
# Step 16170, dloss 0.014
# Step 16180, dloss 0.007
# Step 16190, dloss 0.007
# Step 16200, dloss 0.008
# Step 16210, dloss 0.086
# Step 16220, dloss 0.012
# Step 16230, dloss 0.012
# Step 16240, dloss 0.016
# Step 16250, dloss 0.020
# Step 16260, dloss 0.091
# Step 16270, dloss 0.009
# Step 16280, dloss 0.160
# Step 16290, dloss 0.008
# Step 16300, dloss 0.007
# Step 16310, dloss 0.099
# Step 16320, dloss 0.070
# Step 16330, dloss 0.013
# Step 16340, dloss 0.086
# Step 16350, dloss 0.022
# Step 16360, dloss 0.158
# Step 16370, dloss 0.013
# Step 16380, dloss 0.010
# Step 16390, dloss 0.074
# Step 16400, dloss 0.007
# Step 16410, dloss 0.088
# Step 16420, dloss 0.150
# Step 16430, dloss 0.009
# Step 16440, dloss 0.008
# Step 16450, dloss 0.223
# Step 16460, dloss 0.010
# Step 16470, dloss 0.010
# Step 16480, dloss 0.012
# Step 16490, dloss 0.010
# Step 16500, dloss 0.079
# Step 16510, dloss 0.087
# Step 16520, dloss 0.084
# Step 16530, dloss 0.076
# Step 16540, dloss 0.009
# Step 16550, dloss 0.082
# Step 16560, dloss 0.007
# Step 16570, dloss 0.007
# Step 16580, dloss 0.165
# Step 16590, dloss 0.153
# Step 16600, dloss 0.083
# Step 16610, dloss 0.215
# Step 16620, dloss 0.012
# Step 16630, dloss 0.099
# Step 16640, dloss 0.070
# Step 16650, dloss 0.009
# Step 16660, dloss 0.174
# Step 16670, dloss 0.164
# Step 16680, dloss 0.076
# Step 16690, dloss 0.160
# Step 16700, dloss 0.077
# Step 16710, dloss 0.230
# Step 16720, dloss 0.013
# Step 16730, dloss 0.088
# Step 16740, dloss 0.079
# Step 16750, dloss 0.214
# Step 16760, dloss 0.088
# Step 16770, dloss 0.009
# Step 16780, dloss 0.010
# Step 16790, dloss 0.085
# Step 16800, dloss 0.085
# Step 16810, dloss 0.098
# Step 16820, dloss 0.082
# Step 16830, dloss 0.018
# Step 16840, dloss 0.009
# Step 16850, dloss 0.008
# Step 16860, dloss 0.006
# Step 16870, dloss 0.007
# Step 16880, dloss 0.079
# Step 16890, dloss 0.085
# Step 16900, dloss 0.085
# Step 16910, dloss 0.008
# Step 16920, dloss 0.160
# Step 16930, dloss 0.008
# Step 16940, dloss 0.008
# Step 16950, dloss 0.009
# Step 16960, dloss 0.085
# Step 16970, dloss 0.011
# Step 16980, dloss 0.087
# Step 16990, dloss 0.009
# Step 17000, dloss 0.085
# Step 17010, dloss 0.007
# Step 17020, dloss 0.166
# Step 17030, dloss 0.080
# Step 17040, dloss 0.007
# Step 17050, dloss 0.007
# Step 17060, dloss 0.008
# Step 17070, dloss 0.082
# Step 17080, dloss 0.009
# Step 17090, dloss 0.007
# Step 17100, dloss 0.008
# Step 17110, dloss 0.094
# Step 17120, dloss 0.009
# Step 17130, dloss 0.015
# Step 17140, dloss 0.013
# Step 17150, dloss 0.007
# Step 17160, dloss 0.087
# Step 17170, dloss 0.007
# Step 17180, dloss 0.076
# Step 17190, dloss 0.013
# Step 17200, dloss 0.011
# Step 17210, dloss 0.079
# Step 17220, dloss 0.013
# Step 17230, dloss 0.077
# Step 17240, dloss 0.011
# Step 17250, dloss 0.007
# Step 17260, dloss 0.006
# Step 17270, dloss 0.330
# Step 17280, dloss 0.012
# Step 17290, dloss 0.010
# Step 17300, dloss 0.010
# Step 17310, dloss 0.009
# Step 17320, dloss 0.011
# Step 17330, dloss 0.007
# Step 17340, dloss 0.009
# Step 17350, dloss 0.087
# Step 17360, dloss 0.013
# Step 17370, dloss 0.161
# Step 17380, dloss 0.149
# Step 17390, dloss 0.309
# Step 17400, dloss 0.015
# Step 17410, dloss 0.011
# Step 17420, dloss 0.009
# Step 17430, dloss 0.084
# Step 17440, dloss 0.079
# Step 17450, dloss 0.173
# Step 17460, dloss 0.010
# Step 17470, dloss 0.011
# Step 17480, dloss 0.011
# Step 17490, dloss 0.081
# Step 17500, dloss 0.007
# Step 17510, dloss 0.007
# Step 17520, dloss 0.006
# Step 17530, dloss 0.084
# Step 17540, dloss 0.014
# Step 17550, dloss 0.079
# Step 17560, dloss 0.091
# Step 17570, dloss 0.008
# Step 17580, dloss 0.008
# Step 17590, dloss 0.076
# Step 17600, dloss 0.014
# Step 17610, dloss 0.087
# Step 17620, dloss 0.011
# Step 17630, dloss 0.007
# Step 17640, dloss 0.007
# Step 17650, dloss 0.086
# Step 17660, dloss 0.012
# Step 17670, dloss 0.011
# Step 17680, dloss 0.241
# Step 17690, dloss 0.080
# Step 17700, dloss 0.085
# Step 17710, dloss 0.007
# Step 17720, dloss 0.007
# Step 17730, dloss 0.086
# Step 17740, dloss 0.153
# Step 17750, dloss 0.092
# Step 17760, dloss 0.010
# Step 17770, dloss 0.084
# Step 17780, dloss 0.012
# Step 17790, dloss 0.008
# Step 17800, dloss 0.283
# Step 17810, dloss 0.160
# Step 17820, dloss 0.078
# Step 17830, dloss 0.013
# Step 17840, dloss 0.077
# Step 17850, dloss 0.009
# Step 17860, dloss 0.088
# Step 17870, dloss 0.078
# Step 17880, dloss 0.087
# Step 17890, dloss 0.074
# Step 17900, dloss 0.008
# Step 17910, dloss 0.143
# Step 17920, dloss 0.085
# Step 17930, dloss 0.007
# Step 17940, dloss 0.077
# Step 17950, dloss 0.084
# Step 17960, dloss 0.084
# Step 17970, dloss 0.014
# Step 17980, dloss 0.009
# Step 17990, dloss 0.075
# Step 18000, dloss 0.084
# Step 18010, dloss 0.254
# Step 18020, dloss 0.009
# Step 18030, dloss 0.009
# Step 18040, dloss 0.009
# Step 18050, dloss 0.008
# Step 18060, dloss 0.008
# Step 18070, dloss 0.091
# Step 18080, dloss 0.084
# Step 18090, dloss 0.086
# Step 18100, dloss 0.082
# Step 18110, dloss 0.265
# Step 18120, dloss 0.112
# Step 18130, dloss 0.078
# Step 18140, dloss 0.155
# Step 18150, dloss 0.008
# Step 18160, dloss 0.173
# Step 18170, dloss 0.009
# Step 18180, dloss 0.009
# Step 18190, dloss 0.007
# Step 18200, dloss 0.168
# Step 18210, dloss 0.006
# Step 18220, dloss 0.083
# Step 18230, dloss 0.008
# Step 18240, dloss 0.009
# Step 18250, dloss 0.012
# Step 18260, dloss 0.008
# Step 18270, dloss 0.008
# Step 18280, dloss 0.085
# Step 18290, dloss 0.094
# Step 18300, dloss 0.089
# Step 18310, dloss 0.010
# Step 18320, dloss 0.084
# Step 18330, dloss 0.082
# Step 18340, dloss 0.082
# Step 18350, dloss 0.005
# Step 18360, dloss 0.006
# Step 18370, dloss 0.007
# Step 18380, dloss 0.081
# Step 18390, dloss 0.081
# Step 18400, dloss 0.150
# Step 18410, dloss 0.080
# Step 18420, dloss 0.080
# Step 18430, dloss 0.098
# Step 18440, dloss 0.251
# Step 18450, dloss 0.091
# Step 18460, dloss 0.013
# Step 18470, dloss 0.012
# Step 18480, dloss 0.088
# Step 18490, dloss 0.093
# Step 18500, dloss 0.076
# Step 18510, dloss 0.007
# Step 18520, dloss 0.244
# Step 18530, dloss 0.083
# Step 18540, dloss 0.013
# Step 18550, dloss 0.106
# Step 18560, dloss 0.009
# Step 18570, dloss 0.081
# Step 18580, dloss 0.081
# Step 18590, dloss 0.010
# Step 18600, dloss 0.009
# Step 18610, dloss 0.009
# Step 18620, dloss 0.079
# Step 18630, dloss 0.008
# Step 18640, dloss 0.062
# Step 18650, dloss 0.010
# Step 18660, dloss 0.088
# Step 18670, dloss 0.011
# Step 18680, dloss 0.224
# Step 18690, dloss 0.011
# Step 18700, dloss 0.009
# Step 18710, dloss 0.142
# Step 18720, dloss 0.174
# Step 18730, dloss 0.007
# Step 18740, dloss 0.009
# Step 18750, dloss 0.008
# Step 18760, dloss 0.008
# Step 18770, dloss 0.081
# Step 18780, dloss 0.084
# Step 18790, dloss 0.091
# Step 18800, dloss 0.091
# Step 18810, dloss 0.010
# Step 18820, dloss 0.097
# Step 18830, dloss 0.010
# Step 18840, dloss 0.009
# Step 18850, dloss 0.152
# Step 18860, dloss 0.084
# Step 18870, dloss 0.084
# Step 18880, dloss 0.012
# Step 18890, dloss 0.080
# Step 18900, dloss 0.011
# Step 18910, dloss 0.085
# Step 18920, dloss 0.073
# Step 18930, dloss 0.078
# Step 18940, dloss 0.009
# Step 18950, dloss 0.085
# Step 18960, dloss 0.012
# Step 18970, dloss 0.012
# Step 18980, dloss 0.013
# Step 18990, dloss 0.086
# Step 19000, dloss 0.010
# Step 19010, dloss 0.010
# Step 19020, dloss 0.010
# Step 19030, dloss 0.020
# Step 19040, dloss 0.078
# Step 19050, dloss 0.014
# Step 19060, dloss 0.081
# Step 19070, dloss 0.010
# Step 19080, dloss 0.011
# Step 19090, dloss 0.006
# Step 19100, dloss 0.086
# Step 19110, dloss 0.156
# Step 19120, dloss 0.078
# Step 19130, dloss 0.079
# Step 19140, dloss 0.077
# Step 19150, dloss 0.009
# Step 19160, dloss 0.012
# Step 19170, dloss 0.008
# Step 19180, dloss 0.009
# Step 19190, dloss 0.014
# Step 19200, dloss 0.156
# Step 19210, dloss 0.010
# Step 19220, dloss 0.010
# Step 19230, dloss 0.166
# Step 19240, dloss 0.012
# Step 19250, dloss 0.087
# Step 19260, dloss 0.013
# Step 19270, dloss 0.012
# Step 19280, dloss 0.008
# Step 19290, dloss 0.008
# Step 19300, dloss 0.006
# Step 19310, dloss 0.085
# Step 19320, dloss 0.085
# Step 19330, dloss 0.081
# Step 19340, dloss 0.075
# Step 19350, dloss 0.009
# Step 19360, dloss 0.315
# Step 19370, dloss 0.079
# Step 19380, dloss 0.155
# Step 19390, dloss 0.008
# Step 19400, dloss 0.007
# Step 19410, dloss 0.008
# Step 19420, dloss 0.009
# Step 19430, dloss 0.011
# Step 19440, dloss 0.013
# Step 19450, dloss 0.010
# Step 19460, dloss 0.009
# Step 19470, dloss 0.077
# Step 19480, dloss 0.009
# Step 19490, dloss 0.083
# Step 19500, dloss 0.084
# Step 19510, dloss 0.012
# Step 19520, dloss 0.012
# Step 19530, dloss 0.011
# Step 19540, dloss 0.010
# Step 19550, dloss 0.081
# Step 19560, dloss 0.165
# Step 19570, dloss 0.012
# Step 19580, dloss 0.009
# Step 19590, dloss 0.008
# Step 19600, dloss 0.083
# Step 19610, dloss 0.008
# Step 19620, dloss 0.087
# Step 19630, dloss 0.076
# Step 19640, dloss 0.223
# Step 19650, dloss 0.008
# Step 19660, dloss 0.091
# Step 19670, dloss 0.008
# Step 19680, dloss 0.129
# Step 19690, dloss 0.011
# Step 19700, dloss 0.009
# Step 19710, dloss 0.083
# Step 19720, dloss 0.009
# Step 19730, dloss 0.008
# Step 19740, dloss 0.138
# Step 19750, dloss 0.158
# Step 19760, dloss 0.009
# Step 19770, dloss 0.080
# Step 19780, dloss 0.009
# Step 19790, dloss 0.009
# Step 19800, dloss 0.084
# Step 19810, dloss 0.008
# Step 19820, dloss 0.085
# Step 19830, dloss 0.078
# Step 19840, dloss 0.084
# Step 19850, dloss 0.009
# Step 19860, dloss 0.010
# Step 19870, dloss 0.008
# Step 19880, dloss 0.007
# Step 19890, dloss 0.078
# Step 19900, dloss 0.010
# Step 19910, dloss 0.153
# Step 19920, dloss 0.084
# Step 19930, dloss 0.086
# Step 19940, dloss 0.012
# Step 19950, dloss 0.166
# Step 19960, dloss 0.083
# Step 19970, dloss 0.012
# Step 19980, dloss 0.084
# Step 19990, dloss 0.009
# Step 20000, dloss 0.223
# Step 20010, dloss 0.011
# Step 20020, dloss 0.008
# Step 20030, dloss 0.079
# Step 20040, dloss 0.075
# Step 20050, dloss 0.165
# Step 20060, dloss 0.083
# Step 20070, dloss 0.014
# Step 20080, dloss 0.085
# Step 20090, dloss 0.009
# Step 20100, dloss 0.011
# Step 20110, dloss 0.011
# Step 20120, dloss 0.011
# Step 20130, dloss 0.075
# Step 20140, dloss 0.077
# Step 20150, dloss 0.010
# Step 20160, dloss 0.080
# Step 20170, dloss 0.084
# Step 20180, dloss 0.010
# Step 20190, dloss 0.156
# Step 20200, dloss 0.008
# Step 20210, dloss 0.006
# Step 20220, dloss 0.091
# Step 20230, dloss 0.153
# Step 20240, dloss 0.075
# Step 20250, dloss 0.007
# Step 20260, dloss 0.078
# Step 20270, dloss 0.009
# Step 20280, dloss 0.011
# Step 20290, dloss 0.084
# Step 20300, dloss 0.009
# Step 20310, dloss 0.084
# Step 20320, dloss 0.011
# Step 20330, dloss 0.009
# Step 20340, dloss 0.164
# Step 20350, dloss 0.098
# Step 20360, dloss 0.085
# Step 20370, dloss 0.083
# Step 20380, dloss 0.013
# Step 20390, dloss 0.009
# Step 20400, dloss 0.012
# Step 20410, dloss 0.078
# Step 20420, dloss 0.007
# Step 20430, dloss 0.161
# Step 20440, dloss 0.078
# Step 20450, dloss 0.006
# Step 20460, dloss 0.164
# Step 20470, dloss 0.011
# Step 20480, dloss 0.084
# Step 20490, dloss 0.012
# Step 20500, dloss 0.012
# Step 20510, dloss 0.077
# Step 20520, dloss 0.090
# Step 20530, dloss 0.093
# Step 20540, dloss 0.100
# Step 20550, dloss 0.154
# Step 20560, dloss 0.091
# Step 20570, dloss 0.018
# Step 20580, dloss 0.012
# Step 20590, dloss 0.015
# Step 20600, dloss 0.151
# Step 20610, dloss 0.062
# Step 20620, dloss 0.107
# Step 20630, dloss 0.011
# Step 20640, dloss 0.094
# Step 20650, dloss 0.143
# Step 20660, dloss 0.081
# Step 20670, dloss 0.143
# Step 20680, dloss 0.010
# Step 20690, dloss 0.159
# Step 20700, dloss 0.238
# Step 20710, dloss 0.013
# Step 20720, dloss 0.080
# Step 20730, dloss 0.010
# Step 20740, dloss 0.086
# Step 20750, dloss 0.008
# Step 20760, dloss 0.253
# Step 20770, dloss 0.010
# Step 20780, dloss 0.010
# Step 20790, dloss 0.074
# Step 20800, dloss 0.076
# Step 20810, dloss 0.166
# Step 20820, dloss 0.088
# Step 20830, dloss 0.009
# Step 20840, dloss 0.011
# Step 20850, dloss 0.084
# Step 20860, dloss 0.015
# Step 20870, dloss 0.095
# Step 20880, dloss 0.010
# Step 20890, dloss 0.010
# Step 20900, dloss 0.008
# Step 20910, dloss 0.095
# Step 20920, dloss 0.009
# Step 20930, dloss 0.069
# Step 20940, dloss 0.009
# Step 20950, dloss 0.086
# Step 20960, dloss 0.168
# Step 20970, dloss 0.078
# Step 20980, dloss 0.011
# Step 20990, dloss 0.081
# Step 21000, dloss 0.008
# Step 21010, dloss 0.075
# Step 21020, dloss 0.086
# Step 21030, dloss 0.082
# Step 21040, dloss 0.162
# Step 21050, dloss 0.079
# Step 21060, dloss 0.174
# Step 21070, dloss 0.009
# Step 21080, dloss 0.087
# Step 21090, dloss 0.173
# Step 21100, dloss 0.010
# Step 21110, dloss 0.168
# Step 21120, dloss 0.082
# Step 21130, dloss 0.011
# Step 21140, dloss 0.083
# Step 21150, dloss 0.082
# Step 21160, dloss 0.016
# Step 21170, dloss 0.088
# Step 21180, dloss 0.083
# Step 21190, dloss 0.080
# Step 21200, dloss 0.013
# Step 21210, dloss 0.011
# Step 21220, dloss 0.154
# Step 21230, dloss 0.078
# Step 21240, dloss 0.085
# Step 21250, dloss 0.019
# Step 21260, dloss 0.012
# Step 21270, dloss 0.018
# Step 21280, dloss 0.165
# Step 21290, dloss 0.079
# Step 21300, dloss 0.086
# Step 21310, dloss 0.010
# Step 21320, dloss 0.158
# Step 21330, dloss 0.013
# Step 21340, dloss 0.017
# Step 21350, dloss 0.223
# Step 21360, dloss 0.015
# Step 21370, dloss 0.015
# Step 21380, dloss 0.086
# Step 21390, dloss 0.086
# Step 21400, dloss 0.013
# Step 21410, dloss 0.082
# Step 21420, dloss 0.011
# Step 21430, dloss 0.077
# Step 21440, dloss 0.158
# Step 21450, dloss 0.007
# Step 21460, dloss 0.009
# Step 21470, dloss 0.148
# Step 21480, dloss 0.079
# Step 21490, dloss 0.014
# Step 21500, dloss 0.010
# Step 21510, dloss 0.084
# Step 21520, dloss 0.009
# Step 21530, dloss 0.010
# Step 21540, dloss 0.082
# Step 21550, dloss 0.158
# Step 21560, dloss 0.009
# Step 21570, dloss 0.009
# Step 21580, dloss 0.010
# Step 21590, dloss 0.010
# Step 21600, dloss 0.011
# Step 21610, dloss 0.011
# Step 21620, dloss 0.010
# Step 21630, dloss 0.073
# Step 21640, dloss 0.080
# Step 21650, dloss 0.010
# Step 21660, dloss 0.007
# Step 21670, dloss 0.006
# Step 21680, dloss 0.006
# Step 21690, dloss 0.013
# Step 21700, dloss 0.080
# Step 21710, dloss 0.009
# Step 21720, dloss 0.006
# Step 21730, dloss 0.088
# Step 21740, dloss 0.007
# Step 21750, dloss 0.006
# Step 21760, dloss 0.007
# Step 21770, dloss 0.007
# Step 21780, dloss 0.007
# Step 21790, dloss 0.007
# Step 21800, dloss 0.007
# Step 21810, dloss 0.009
# Step 21820, dloss 0.158
# Step 21830, dloss 0.077
# Step 21840, dloss 0.010
# Step 21850, dloss 0.083
# Step 21860, dloss 0.150
# Step 21870, dloss 0.012
# Step 21880, dloss 0.080
# Step 21890, dloss 0.091
# Step 21900, dloss 0.082
# Step 21910, dloss 0.011
# Step 21920, dloss 0.009
# Step 21930, dloss 0.011
# Step 21940, dloss 0.077
# Step 21950, dloss 0.087
# Step 21960, dloss 0.009
# Step 21970, dloss 0.011
# Step 21980, dloss 0.014
# Step 21990, dloss 0.014
# Step 22000, dloss 0.013
# Step 22010, dloss 0.078
# Step 22020, dloss 0.009
# Step 22030, dloss 0.107
# Step 22040, dloss 0.009
# Step 22050, dloss 0.009
# Step 22060, dloss 0.078
# Step 22070, dloss 0.087
# Step 22080, dloss 0.013
# Step 22090, dloss 0.086
# Step 22100, dloss 0.068
# Step 22110, dloss 0.010
# Step 22120, dloss 0.010
# Step 22130, dloss 0.081
# Step 22140, dloss 0.008
# Step 22150, dloss 0.009
# Step 22160, dloss 0.073
# Step 22170, dloss 0.009
# Step 22180, dloss 0.082
# Step 22190, dloss 0.007
# Step 22200, dloss 0.094
# Step 22210, dloss 0.080
# Step 22220, dloss 0.008
# Step 22230, dloss 0.008
# Step 22240, dloss 0.086
# Step 22250, dloss 0.228
# Step 22260, dloss 0.087
# Step 22270, dloss 0.015
# Step 22280, dloss 0.074
# Step 22290, dloss 0.082
# Step 22300, dloss 0.096
# Step 22310, dloss 0.013
# Step 22320, dloss 0.012
# Step 22330, dloss 0.007
# Step 22340, dloss 0.008
# Step 22350, dloss 0.081
# Step 22360, dloss 0.011
# Step 22370, dloss 0.012
# Step 22380, dloss 0.013
# Step 22390, dloss 0.012
# Step 22400, dloss 0.089
# Step 22410, dloss 0.087
# Step 22420, dloss 0.098
# Step 22430, dloss 0.082
# Step 22440, dloss 0.010
# Step 22450, dloss 0.095
# Step 22460, dloss 0.018
# Step 22470, dloss 0.013
# Step 22480, dloss 0.078
# Step 22490, dloss 0.011
# Step 22500, dloss 0.138
# Step 22510, dloss 0.087
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d9aad37c427a> in <module>
#      32         y_lie = np.ones([BATCH_SIZE, 1])
#      33         noise = np.random.normal(loc=0., scale=1., size=[BATCH_SIZE, LATENT_DIM])
# ---> 34         a_loss = ADV.train_on_batch(noise, y_lie)
#      35         tf.summary.image('lat_sample', GEN.predict(np.random.randn(4, LATENT_DIM)))
#      36         tf.summary.image('random_draw', GEN.predict(image_lat))
#
# ~/projects/gan/began/envs/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#     971       outputs = training_v2_utils.train_on_batch(
#     972           self, x, y=y, sample_weight=sample_weight,
# --> 973           class_weight=class_weight, reset_metrics=reset_metrics)
#     974       outputs = (outputs['total_loss'] + outputs['output_losses'] +
#     975                  outputs['metrics'])
#
# ~/projects/gan/began/envs/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics)
#     262       y,
#     263       sample_weights=sample_weights,
# --> 264       output_loss_metrics=model._output_loss_metrics)
#     265
#     266   if reset_metrics:
#
# ~/projects/gan/began/envs/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     309           sample_weights=sample_weights,
#     310           training=True,
# --> 311           output_loss_metrics=output_loss_metrics))
#     312   if not isinstance(outs, list):
#     313     outs = [outs]
#
# ~/projects/gan/began/envs/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     266           model._backwards(tape, scaled_total_loss)
#     267         else:
# --> 268           grads = tape.gradient(scaled_total_loss, trainable_weights)
#     269           if isinstance(model.optimizer,
#     270                         loss_scale_optimizer.LossScaleOptimizer):
#
# ~/projects/gan/began/envs/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1012         output_gradients=output_gradients,
#    1013         sources_raw=flat_sources_raw,
# -> 1014         unconnected_gradients=unconnected_gradients)
#    1015
#    1016     if not self._persistent:
#
# ~/projects/gan/began/envs/lib/python3.7/site-packages/tensorflow_core/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      74       output_gradients,
#      75       sources_raw,
# ---> 76       compat.as_str(unconnected_gradients.value))
#
# ~/projects/gan/began/envs/lib/python3.7/site-packages/tensorflow_core/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices)
#     136     return [None] * num_inputs
#     137
# --> 138   return grad_fn(mock_op, *out_grads)
#     139
#     140
#
# ~/projects/gan/began/envs/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_grad.py in _BiasAddGrad(op, received_grad)
#     348   return (received_grad,
#     349           gen_nn_ops.bias_add_grad(
# --> 350               out_backprop=received_grad, data_format=data_format))
#     351
#     352
#
# ~/projects/gan/began/envs/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in bias_add_grad(out_backprop, data_format, name)
#     825         _ctx._context_handle, _ctx._thread_local_data.device_name,
#     826         "BiasAddGrad", name, _ctx._post_execution_callbacks, out_backprop,
# --> 827         "data_format", data_format)
#     828       return _result
#     829     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
plt.imshow(ADV.get_layer('Generator').predict(np.random.randn(1, 16))[0, :, :, 0])

# %%
trained_model.save(os.fspath(MODEL_PATH))
